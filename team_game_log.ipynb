# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup as BS

# %%
teamid = ['BOS', 'PHI', 'BRK', 'TOR', 'NYK']



for team in teamid:
    gamelog = pd.read_html(f'https://www.basketball-reference.com/teams/{team}/2023/gamelog/', header = 1)
    
    print(gamelog)
# Out:
# [     Rk    G        Date Unnamed: 3  Opp  W/L   Tm Opp.1    FG   FGA  ...  \
# 0     1    1  2022-10-18        NaN  PHI    W  126   117    46    82  ...
# 1     2    2  2022-10-21          @  MIA    W  111   104    41    79  ...
# 2     3    3  2022-10-22          @  ORL    W  126   120    42    87  ...
# 3     4    4  2022-10-24          @  CHI    L  102   120    37   100  ...
# 4     5    5  2022-10-28        NaN  CLE    L  123   132    42    82  ...
# 5     6    6  2022-10-30        NaN  WAS    W  112    94    36    79  ...
# 6     7    7  2022-11-02          @  CLE    L  113   114    38    93  ...
# 7     8    8  2022-11-04        NaN  CHI    W  123   119    41    83  ...
# 8     9    9  2022-11-05          @  NYK    W  133   118    47    88  ...
# 9    10   10  2022-11-07          @  MEM    W  109   106    38    82  ...
# 10   11   11  2022-11-09        NaN  DET    W  128   112    47    88  ...
# 11   12   12  2022-11-11        NaN  DEN    W  131   112    50    90  ...
# ...
